# %%
import pandas as pd
import re
import emoji as emj

EMOJIS = emj.UNICODE_EMOJI["en"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 import pandas as pd
#       2 import re
# ----> 3 import emoji as emj
#       5 EMOJIS = emj.UNICODE_EMOJI["en"]
#
# ModuleNotFoundError: No module named 'emoji'

# %%
df = pd.read_json('../channel_messages.json')

# %%
df
# Out:
#                  _   id                                         peer_id  \
# 0          Message  106  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 1          Message  105  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 2          Message  104  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 3          Message  103  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 4          Message   95  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 5          Message   92  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 6          Message   91  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 7          Message   89  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 8          Message   83  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 9          Message   80  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 10         Message   76  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 11         Message   75  {'_': 'PeerChannel', 'channel_id': 1746611944}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _                   45 non-null     object
#  1   id                  45 non-null     int64
#  2   peer_id             45 non-null     object
#  3   date                45 non-null     datetime64[ns, UTC]
#  4   message             44 non-null     object
#  5   out                 45 non-null     bool
#  6   mentioned           45 non-null     bool
#  7   media_unread        45 non-null     bool
#  8   silent              45 non-null     bool
#  9   post                45 non-null     bool
#  10  from_scheduled      44 non-null     float64
#  11  legacy              45 non-null     bool
#  12  edit_hide           44 non-null     float64
#  13  pinned              44 non-null     float64
#  14  from_id             0 non-null      float64
# ...

# %%
edu_info = df['message'].eq('university','університет','стипендія').any()

# %%
def getLinks(df):
    pattern = re.compile(r"(?<=://)(.*)(?=</url)")
    df['Links'] = df['message'].str.extract(pattern, expand=False)

# %%
getLinks(df)

# %%
df.head()
# Out:
#          _   id                                         peer_id  \
# 0  Message  106  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 1  Message  105  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 2  Message  104  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 3  Message  103  {'_': 'PeerChannel', 'channel_id': 1746611944}
# 4  Message   95  {'_': 'PeerChannel', 'channel_id': 1746611944}
#
#                        date  \
# 0 2022-05-19 12:52:59+00:00
# 1 2022-05-19 12:52:45+00:00
# 2 2022-05-19 12:51:10+00:00
# 3 2022-05-19 12:48:43+00:00
# 4 2022-04-11 12:10:21+00:00
#
#                                              message    out  mentioned  \
# 0  Дорогі друзі!\n\nДеякий час від нас не було но...  False      False
# 1  🇦🇷Аргентина\n\nЗагальна інформація \nГарячі лі...  False      False
# 2  🇮🇸Ісландія\n\nЗагальна інформація \nГарячі лін...  False      False
# 3  🇮🇱Ізраїль\n\nЗагальна інформація \nГарячі ліні...  False      False
# ...

# %%
def extract_emoji(df):
    df["countries"] = ""
    for index, row in df.iterrows():
        for emoji in EMOJIS:
            if emoji in row["message"]:
                row["message"] = row["message"].replace(emoji, "")
                row["countries"] += emoji

edu_info = extract_emoji(df)
print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 9>()
#       6                 row["message"] = row["message"].replace(emoji, "")
#       7                 row["countries"] += emoji
# ----> 9 edu_info = extract_emoji(df)
#      10 print(df.to_string())
#
# Input In [28], in extract_emoji(df)
#       2 df["countries"] = ""
#       3 for index, row in df.iterrows():
# ----> 4     for emoji in EMOJIS:
#       5         if emoji in row["message"]:
#       6             row["message"] = row["message"].replace(emoji, "")
#
# NameError: name 'EMOJIS' is not defined
